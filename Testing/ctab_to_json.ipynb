# %% [markdown]
# # CTAB to JSON

# %% [markdown]
# Taking gtmseg.ctab (FreeSurfer's expanded color table) and converting it to JSON dictionary.

# %%
import pandas as pd
import json
import numpy as np

# %%
fields = ['region_index','name','color_r','color_g','color_b','alpha','tissue_type']
ctab = pd.read_csv('gtmseg.ctab',sep='\s+',comment='#',names=fields)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_2308495/441283904.py:2: SyntaxWarning: invalid escape sequence '\s'
#   ctab = pd.read_csv('gtmseg.ctab',sep='\s+',comment='#',names=fields)

# %%
ctab
# Out:
#      region_index                        name  color_r  color_g  color_b  \
# 0               0                     Unknown        0        0        0
# 1               1      Left-Cerebral-Exterior       70      130      180
# 2               2  Left-Cerebral-White-Matter      245      245      245
# 3               4      Left-Lateral-Ventricle      120       18      134
# 4               5           Left-Inf-Lat-Vent      196       58      250
# ..            ...                         ...      ...      ...      ...
# 106          2031        ctx-rh-supramarginal       80      160       20
# 107          2032          ctx-rh-frontalpole      100        0      100
# 108          2033         ctx-rh-temporalpole       70       20      170
# 109          2034   ctx-rh-transversetemporal      150      150      200
# 110          2035               ctx-rh-insula      255      192       32
#
#      alpha  tissue_type
# 0        0            0
# 1        0            5
# ...
